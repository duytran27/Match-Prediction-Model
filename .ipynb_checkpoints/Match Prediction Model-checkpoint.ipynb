# %%
import pandas as pd

import warnings

warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('/Users/Duy Tran/FootballAnalytics/Project 2 - Match Prediction Model/project2.csv')

# %%
df.head()
# Out:
#     Wk  Day        Date   Time        Home   xG Score  xG.1           Away  \
# 0  1.0  Fri  2018-08-17  20:15      Girona  0.7   0–0   0.0     Valladolid
# 1  1.0  Fri  2018-08-17  22:15       Betis  0.9   0–3   2.5        Levante
# 2  1.0  Sat  2018-08-18  18:15  Celta Vigo  0.6   1–1   0.6       Espanyol
# 3  1.0  Sat  2018-08-18  20:15  Villarreal  1.6   1–2   0.7  Real Sociedad
# 4  1.0  Sat  2018-08-18  22:15   Barcelona  3.2   3–0   0.3         Alavés
#
#    Attendance                          Venue           Referee
# 0     10368.0  Estadi Municipal de Montilivi  Guillermo Cuadra
# 1     46225.0      Estadio Benito Villamarín  Ignacio Iglesias
# 2     16215.0            Estadio de Balaídos    Santiago Jaime
# 3     16250.0         Estadio de la Cerámica      Mario Melero
# 4     52356.0                       Camp Nou      José Sánchez

# %%
df.shape
# Out:
# (4560, 12)

# %%
#Display null values
df[df.isnull().any(axis=1)]
# Out:
#         Wk  Day        Date   Time            Home   xG Score  xG.1  \
# 1029  24.0  Tue  2020-03-10  20:00           Eibar  2.0   1–2   1.2
# 1030  28.0  Thu  2020-06-11  22:00         Sevilla  1.7   2–0   0.5
# 1031  28.0  Fri  2020-06-12  19:30         Granada  2.3   2–1   0.6
# 1032  28.0  Fri  2020-06-12  22:00        Valencia  1.0   1–1   1.4
# 1033  28.0  Sat  2020-06-13  14:00        Espanyol  2.5   2–0   0.1
# ...    ...  ...         ...    ...             ...  ...   ...   ...
# 4555  38.0  Sun  2024-05-19  16:00       Brentford  NaN   NaN   NaN
# 4556  38.0  Sun  2024-05-19  16:00         Chelsea  NaN   NaN   NaN
# 4557  38.0  Sun  2024-05-19  16:00  Crystal Palace  NaN   NaN   NaN
# 4558  38.0  Sun  2024-05-19  16:00       Liverpool  NaN   NaN   NaN
# 4559  38.0  Sun  2024-05-19  16:00         Burnley  NaN   NaN   NaN
#
#                  Away  Attendance                          Venue  \
# 1029    Real Sociedad         NaN    Estadio Municipal de Ipurúa
# 1030            Betis         NaN  Estadio Ramón Sánchez Pizjuán
# 1031           Getafe         NaN     Estadio Nuevo Los Cármenes
# 1032          Levante         NaN            Estadio de Mestalla
# 1033           Alavés         NaN                   RCDE Stadium
# ...               ...         ...                            ...
# 4555    Newcastle Utd         NaN        Gtech Community Stadium
# 4556      Bournemouth         NaN                Stamford Bridge
# 4557      Aston Villa         NaN                  Selhurst Park
# 4558           Wolves         NaN                        Anfield
# 4559  Nott'ham Forest         NaN                      Turf Moor
#
#                   Referee
# 1029          David Medié
# 1030  Antonio Matéu Lahoz
# 1031          David Medié
# 1032       Alberola Rojas
# 1033       Pablo González
# ...                   ...
# 4555                  NaN
# 4556                  NaN
# 4557                  NaN
# 4558                  NaN
# 4559                  NaN
#
# [1058 rows x 12 columns]

# %%
#Drop null values in Attendance, Time, Score columns
df = df.dropna(subset = ['Attendance', 'Time', 'Score'])

# %%
df.head()
# Out:
#     Wk  Day        Date   Time        Home   xG Score  xG.1           Away  \
# 0  1.0  Fri  2018-08-17  20:15      Girona  0.7   0–0   0.0     Valladolid
# 1  1.0  Fri  2018-08-17  22:15       Betis  0.9   0–3   2.5        Levante
# 2  1.0  Sat  2018-08-18  18:15  Celta Vigo  0.6   1–1   0.6       Espanyol
# 3  1.0  Sat  2018-08-18  20:15  Villarreal  1.6   1–2   0.7  Real Sociedad
# 4  1.0  Sat  2018-08-18  22:15   Barcelona  3.2   3–0   0.3         Alavés
#
#    Attendance                          Venue           Referee
# 0     10368.0  Estadi Municipal de Montilivi  Guillermo Cuadra
# 1     46225.0      Estadio Benito Villamarín  Ignacio Iglesias
# 2     16215.0            Estadio de Balaídos    Santiago Jaime
# 3     16250.0         Estadio de la Cerámica      Mario Melero
# 4     52356.0                       Camp Nou      José Sánchez

# %%
#Split score into home and away score
df[['home_goals', 'away_goals']] = df['Score'].str.split('–', expand=True).astype(int)

# %%
def determine_result(row):
    if row['home_goals'] > row['away_goals']:
        return 'Home win'
    elif row['home_goals'] < row['away_goals']:
        return 'Away win'
    else:
        return 'Draw'

df['result'] = df.apply(determine_result, axis=1)

# %%
#Convert day into date time variable
df['Date'] = pd.to_datetime(df['Date'])

df['Day'] = df['Date'].dt.day_name()

# %%
#Add season start column
df['season_start'] = df['Date'].apply(lambda x: x.year -1 if x.month < 8 else x.year)

# %%
df.head()
# Out:
#     Wk       Day       Date   Time        Home   xG Score  xG.1  \
# 0  1.0    Friday 2018-08-17  20:15      Girona  0.7   0–0   0.0
# 1  1.0    Friday 2018-08-17  22:15       Betis  0.9   0–3   2.5
# 2  1.0  Saturday 2018-08-18  18:15  Celta Vigo  0.6   1–1   0.6
# 3  1.0  Saturday 2018-08-18  20:15  Villarreal  1.6   1–2   0.7
# 4  1.0  Saturday 2018-08-18  22:15   Barcelona  3.2   3–0   0.3
#
#             Away  Attendance                          Venue           Referee  \
# 0     Valladolid     10368.0  Estadi Municipal de Montilivi  Guillermo Cuadra
# 1        Levante     46225.0      Estadio Benito Villamarín  Ignacio Iglesias
# 2       Espanyol     16215.0            Estadio de Balaídos    Santiago Jaime
# 3  Real Sociedad     16250.0         Estadio de la Cerámica      Mario Melero
# 4         Alavés     52356.0                       Camp Nou      José Sánchez
#
#    home_goals  away_goals    result  season_start
# 0           0           0      Draw          2018
# 1           0           3  Away win          2018
# 2           1           1      Draw          2018
# 3           1           2  Away win          2018
# 4           3           0  Home win          2018

# %%
#Convert Day into boolean values so the model can read
df = pd.get_dummies(df, columns=['Day'])

# %%
#Reset index so the order is not messed up
df.reset_index(drop=True, inplace=True)

# %%
#Creating a temporary dataset to add average goals for home and away teams
for x in df.Home.unique():
    temp_df = df[(df['Home'] == x) | (df['Away'] == x)]
    temp_df = temp_df.sort_values(['Date'])
    
    #Assign correct goal values for each team
    temp_df['goal_value_to_calculate'] = temp_df.apply(lambda y: y['home_goals'] if y['Home'] == x else y['away_goals'], axis=1)
    
    #Roll into last 5 goals of a team to calculate the average
    temp_df['rolling_avg_goals'] = temp_df['goal_value_to_calculate'].rolling(window=5, closed='left', min_periods=1).mean()
    
    #Seperate rolling avg goals for home and away teams
    for index, row in temp_df.iterrows():
        if row['Home'] == x:
            df.at[index, 'home_rolling_avg_goals'] = row['rolling_avg_goals']
        else:
            df.at[index, 'away_rolling_avg_goals'] = row['rolling_avg_goals']

# %%
#Creating a temporary dataset to add xG(expected goals) for home and away teams

for x in df.Home.unique():
    temp_df = df[(df['Home'] == x) | (df['Away'] == x)]
    temp_df = temp_df.sort_values(['Date'])
    
    #Assign correct goal values for each team
    temp_df['xG_value_to_calculate'] = temp_df.apply(lambda y: y['xG'] if y['Home'] == x else y['xG.1'], axis=1)
    
    #Roll into last 5 goals of a team to calculate the average
    temp_df['rolling_avg_xG'] = temp_df['xG_value_to_calculate'].rolling(window=5, closed='left', min_periods=1).mean()
    
    #Seperate rolling avg goals for home and away teams
    for index, row in temp_df.iterrows():
        if row['Home'] == x:
            df.at[index, 'home_rolling_avg_xG'] = row['rolling_avg_xG']
        else:
            df.at[index, 'away_rolling_avg_xG'] = row['rolling_avg_xG']

# %%
df.head()
# Out:
#     Wk       Date   Time        Home   xG Score  xG.1           Away  \
# 0  1.0 2018-08-17  20:15      Girona  0.7   0–0   0.0     Valladolid
# 1  1.0 2018-08-17  22:15       Betis  0.9   0–3   2.5        Levante
# 2  1.0 2018-08-18  18:15  Celta Vigo  0.6   1–1   0.6       Espanyol
# 3  1.0 2018-08-18  20:15  Villarreal  1.6   1–2   0.7  Real Sociedad
# 4  1.0 2018-08-18  22:15   Barcelona  3.2   3–0   0.3         Alavés
#
#    Attendance                          Venue  ... Day_Monday  Day_Saturday  \
# 0     10368.0  Estadi Municipal de Montilivi  ...      False         False
# 1     46225.0      Estadio Benito Villamarín  ...      False         False
# 2     16215.0            Estadio de Balaídos  ...      False          True
# 3     16250.0         Estadio de la Cerámica  ...      False          True
# 4     52356.0                       Camp Nou  ...      False          True
#
#    Day_Sunday Day_Thursday  Day_Tuesday  Day_Wednesday  \
# 0       False        False        False          False
# 1       False        False        False          False
# 2       False        False        False          False
# 3       False        False        False          False
# 4       False        False        False          False
#
#    home_rolling_avg_goals  away_rolling_avg_goals  home_rolling_avg_xG  \
# 0                     NaN                     NaN                  NaN
# 1                     NaN                     NaN                  NaN
# 2                     NaN                     NaN                  NaN
# 3                     NaN                     NaN                  NaN
# 4                     NaN                     NaN                  NaN
#
#    away_rolling_avg_xG
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
#
# [5 rows x 26 columns]

# %%
#Drop null values 
df = df.dropna(subset=['home_rolling_avg_goals', 'away_rolling_avg_goals', 'home_rolling_avg_xG', 'away_rolling_avg_xG'])

# %%
#Looking at team Brighton stats
df[(df['Home'] == 'Brighton') | (df['Away'] == 'Brighton')] [['Date', 'Home', 'Away', 'xG', 'xG.1', 'home_rolling_avg_xG', 'away_rolling_avg_xG']]
# Out:
#            Date         Home             Away   xG  xG.1  home_rolling_avg_xG  \
# 398  2018-08-19     Brighton   Manchester Utd  1.7   1.4             0.300000
# 405  2018-08-25    Liverpool         Brighton  1.6   0.6             3.300000
# 412  2018-09-01     Brighton           Fulham  2.8   1.6             0.866667
# 429  2018-09-17  Southampton         Brighton  2.0   1.4             1.500000
# 437  2018-09-22     Brighton        Tottenham  0.8   1.9             1.360000
# ...         ...          ...              ...  ...   ...                  ...
# 3440 2024-03-02       Fulham         Brighton  1.3   1.3             1.480000
# 3457 2024-03-10     Brighton  Nott'ham Forest  0.4   0.7             1.640000
# 3473 2024-03-31    Liverpool         Brighton  2.8   0.5             2.720000
# 3481 2024-04-03    Brentford         Brighton  0.6   1.1             1.600000
# 3491 2024-04-06     Brighton          Arsenal  0.5   3.4             0.940000
#
#       away_rolling_avg_xG
# 398                  1.50
# 405                  1.00
# 412                  1.20
# 429                  1.35
# 437                  1.54
# ...                   ...
# 3440                 1.56
# 3457                 1.68
# 3473                 1.44
# 3481                 1.30
# 3491                 1.56
#
# [174 rows x 7 columns]

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

# %%
df.columns
# Out:
# Index(['Wk', 'Date', 'Time', 'Home', 'xG', 'Score', 'xG.1', 'Away',
#        'Attendance', 'Venue', 'Referee', 'home_goals', 'away_goals', 'result',
#        'season_start', 'Day_Friday', 'Day_Monday', 'Day_Saturday',
#        'Day_Sunday', 'Day_Thursday', 'Day_Tuesday', 'Day_Wednesday',
#        'home_rolling_avg_goals', 'away_rolling_avg_goals',
#        'home_rolling_avg_xG', 'away_rolling_avg_xG'],
#       dtype='object')

# %%
#Drop unnecessary columns for model training
features = [column for column in df.drop(columns=['Date', 'xG', 'xG.1', 'Home', 'Away', 'Referee', 'Venue', 'Score', 'result',
                                                 'home_goals', 'away_goals', 'season_start', 'Time', 'Attendance'])]

# %%
features
# Out:
# ['Wk',
#  'Day_Friday',
#  'Day_Monday',
#  'Day_Saturday',
#  'Day_Sunday',
#  'Day_Thursday',
#  'Day_Tuesday',
#  'Day_Wednesday',
#  'home_rolling_avg_goals',
#  'away_rolling_avg_goals',
#  'home_rolling_avg_xG',
#  'away_rolling_avg_xG']

# %%
train_data = df[df['season_start'] <= 2022]
test_data = df[df['season_start'] == 2023]

X_train = train_data[features]
y_train = train_data ['result']

X_test = test_data[features]
y_test = test_data['result']
